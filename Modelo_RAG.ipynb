# %% [markdown]
# **O objetivo do exercício desta semana é construir um sistema de RAG combinando busca e LLMs.**
#
# **Etapa 1: Segmentação do texto** - o método usado para segmentação (aka. chucking e janelamento) é livre. A sugestão é usar as ferramentas do langchain.
#
# **Etapa 2: Computação das embeddings e indexação** - A ideia é usar busca densa, usando um modelo de embeddings para criar representações vetoriais para os segmentos obtidos na etap 1. Fiquem livres para usar qualquer modelo, mas sugerimos os modelos do sentence-transformers. Usem o FAISS para criar e gerenciar o índice.
#
# **Etapa 3: Geração das respostas (prompt)** - o LLM usado também é livre. Não fica muito caro usar o gpt-4o-mini, opções free são a API da groq e Ollama. Para esta etapa, usem apenas 150 perguntas (10% do dataset).
#
# **Etapa 4: Avaliação**  -  É talvez o ponto mais importante do trabalho. Sugerimos uma avaliação com a métrica F1-bag-of-words (ver slide 167).

# %%
# Instala as bibliotecas langchain, sentence_transformers e groq
# !pip install -qU langchain sentence_transformers groq

# Instala bibliotecas complementares do langchain, como integração com Hugging Face e a comunidade langchain
# !pip install -qU langchain-huggingface langchain-community

# Instala a biblioteca FAISS para operações eficientes de pesquisa de vetores em CPU
# !pip install -qU faiss-cpu

# Instala o módulo langchain-text-splitter, usado para dividir textos em partes menores
# !pip install -qU langchain-text-splitter

# Baixa o conjunto de dados de teste IIRC
# !wget https://iirc-dataset.s3.us-west-2.amazonaws.com/iirc_test.json

# Baixa o arquivo compactado contendo artigos de contexto
# !wget https://iirc-dataset.s3.us-west-2.amazonaws.com/context_articles.tar.gz

# Extrai os arquivos do contexto dos artigos compactados
# !tar -xf context_articles.tar.gz
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain-text-splitter (from versions: none)
# ERROR: No matching distribution found for langchain-text-splitter
# --2024-10-02 16:39:08--  https://iirc-dataset.s3.us-west-2.amazonaws.com/iirc_test.json
# Resolving iirc-dataset.s3.us-west-2.amazonaws.com (iirc-dataset.s3.us-west-2.amazonaws.com)... 3.5.82.196, 52.92.147.250, 3.5.86.133, ...
# Connecting to iirc-dataset.s3.us-west-2.amazonaws.com (iirc-dataset.s3.us-west-2.amazonaws.com)|3.5.82.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2874825 (2.7M) [application/json]
# Saving to: ‘iirc_test.json.2’
#
# iirc_test.json.2    100%[===================>]   2.74M  4.60MB/s    in 0.6s
#
# 2024-10-02 16:39:10 (4.60 MB/s) - ‘iirc_test.json.2’ saved [2874825/2874825]
#
# --2024-10-02 16:39:10--  https://iirc-dataset.s3.us-west-2.amazonaws.com/context_articles.tar.gz
# Resolving iirc-dataset.s3.us-west-2.amazonaws.com (iirc-dataset.s3.us-west-2.amazonaws.com)... 3.5.82.196, 52.92.147.250, 3.5.86.133, ...
# Connecting to iirc-dataset.s3.us-west-2.amazonaws.com (iirc-dataset.s3.us-west-2.amazonaws.com)|3.5.82.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 385263479 (367M) [application/x-gzip]
# Saving to: ‘context_articles.tar.gz.2’
#
# context_articles.ta 100%[===================>] 367.42M  41.2MB/s    in 9.6s
#
# 2024-10-02 16:39:20 (38.5 MB/s) - ‘context_articles.tar.gz.2’ saved [385263479/385263479]

# %%
# Importa o divisor de texto de caracteres recursivo da biblioteca langchain_text_splitters
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Importa a classe para embeddings da Hugging Face da biblioteca langchain_huggingface
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

# Importa métricas de avaliação do scikit-learn: precisão, recall e F1-score
from sklearn.metrics import precision_score, recall_score, f1_score

# Importa Counter para contagem de elementos
from collections import Counter

# Importa a biblioteca Groq
from groq import Groq

# Importa a barra de progresso do tqdm
from tqdm import tqdm

# Importa a biblioteca NumPy para operações matemáticas e manipulação de arrays
import numpy as np

# Importa o módulo JSON para trabalhar com arquivos JSON
import json

# Importa a biblioteca FAISS para realizar operações de busca em vetores
import faiss


from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Union, Dict, Any

# %%
# Define a chave da API diretamente no código
API_KEY = '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'

# %%
# @title Carregar dados

# Carrega os artigos de contexto a partir do arquivo JSON "context_articles.json"
context_articles = json.load(open("context_articles.json", 'r'))

# Carrega o conjunto de dados de teste a partir do arquivo JSON "iirc_test.json"
data = json.load(open("iirc_test.json", 'r'))

# %%
# Função para excluir respostas do tipo 'none' e adicionar o título às perguntas
def exclude_none_answers(data):
    filtered_data = []
    for item in data:
        # Filtra as perguntas válidas e adiciona o título a cada uma sem modificar o original
        filtered_questions = [
            {**question, 'title': item['title']}
            for question in item['questions']
            if question['answer']['type'] != 'none'
        ]
        # Se houver perguntas filtradas, adiciona ao resultado
        if filtered_questions:
            filtered_item = item.copy()
            filtered_item['questions'] = filtered_questions
            filtered_data.append(filtered_item)
    return filtered_data

# Imprime o número total de itens antes da filtragem
print(f'Total de itens: {len(data)}')

# Filtra as respostas do conjunto de dados original
filter_data = exclude_none_answers(data)

# Imprime o número de itens após a filtragem
print(f'Itens após filtragem: {len(filter_data)}')

# Exibe uma amostra dos dados filtrados
print("\n===> Mostrar um exemplo <===")
print(filter_data[0])
# Out:
# Total de itens: 514
# Itens após filtragem: 435
#
# ===> Mostrar um exemplo <===
# {'questions': [{'answer': {'type': 'span', 'answer_spans': [{'text': 'sky and thunder god', 'passage': 'zeus', 'type': 'answer', 'start': 83, 'end': 102}]}, 'question': 'What is Zeus know for in Greek mythology?', 'context': [{'text': 'he Palici the sons of Zeus', 'passage': 'main', 'indices': [684, 710]}, {'text': 'in Greek mythology', 'passage': 'main', 'indices': [137, 155]}, {'text': 'Zeus (British English , North American English ; , Zeús ) is the sky and thunder god in ancient Greek religion', 'passage': 'Zeus', 'indices': [0, 110]}], 'question_links': ['Greek mythology', 'Zeus'], 'title': 'Palici'}], 'text': "The Palici (Παλικοί in Greek), or Palaci, were a pair of indigenous Sicilian chthonic deities in Roman mythology, and to a lesser extent in Greek mythology. They are mentioned in Ovid's Metamorphoses V, 406, and in Virgil's Aeneid IX, 585. Their cult centered on three small lakes that emitted sulphurous vapors in the Palagonia plain, and as a result these twin brothers were associated with geysers and the underworld. There was also a shrine to the Palaci in Palacia, where people could subject themselves or others to tests of reliability through divine judgement; passing meant that an oath could be trusted. The mythological lineage of the Palici is uncertain; one legend made the Palici the sons of Zeus, or possibly Hephaestus, by Aetna or Thalia, but another claimed that the Palici were the sons of the Sicilian deity Adranus.\n", 'links': [{'target': 'Sicily', 'indices': [68, 76]}, {'target': 'Chthonic', 'indices': [77, 85]}, {'target': 'Roman mythology', 'indices': [97, 112]}, {'target': 'Greek mythology', 'indices': [140, 155]}, {'target': 'Ovid', 'indices': [179, 183]}, {'target': 'Virgil', 'indices': [215, 221]}, {'target': 'Palagonia', 'indices': [319, 328]}, {'target': 'Geyser', 'indices': [393, 400]}, {'target': 'Zeus', 'indices': [706, 710]}, {'target': 'Hephaestus', 'indices': [724, 734]}, {'target': 'Aetna (nymph)', 'indices': [739, 744]}, {'target': 'Thalia (nymph)', 'indices': [748, 754]}, {'target': 'Adranus', 'indices': [828, 835]}], 'title': 'Palici'}

# %%
# @title Carregar documentos
# Adaptado de Visconde https://github.com/neuralmind-ai/visconde

# Número de perguntas que serão usadas para carregar documentos
num_questions = 150

documents = []  # Lista para armazenar os documentos carregados
all_titles = set()  # Conjunto para armazenar os títulos de documentos já adicionados

# Itera sobre os primeiros 'num_questions' itens dos dados filtrados
for item in filter_data[:num_questions]:
    item_title = item['title']
    item_title_lower = item_title.lower()
    # Verifica se o título do item ainda não foi adicionado
    if item_title_lower not in all_titles:
        # Adiciona o documento contendo o título e o texto do item
        documents.append({
            "title": item_title,
            "content": item["text"]
        })
        all_titles.add(item_title_lower)  # Adiciona o título ao conjunto de títulos utilizados

    # Itera sobre os links do item atual, se existirem
    for link in item.get("links", []):
        link_target = link['target']
        link_target_lower = link_target.lower()
        # Verifica se o alvo do link está nos artigos de contexto e ainda não foi adicionado
        if link_target_lower in context_articles and link_target_lower not in all_titles:
            # Adiciona o documento do artigo de contexto correspondente
            documents.append({
                "title": link_target,
                "content": context_articles[link_target_lower]
            })
            all_titles.add(link_target_lower)  # Adiciona o título ao conjunto de títulos utilizados
        else:
            # Imprime uma mensagem informando que o documento já foi carregado ou não está disponível
            print(f"Documento já carregado ou não encontrado: {link_target_lower}")

# Imprime o número total de documentos carregados
print(f'Total de documentos: {len(documents)}')
# Out:
# Documento já carregado ou não encontrado: 9th paratroopers assault regiment "col moschin"
# Documento já carregado ou não encontrado: goldfinger (film)
# Documento já carregado ou não encontrado: list of international cricket council members
# Documento já carregado ou não encontrado: icc americas championship
# Documento já carregado ou não encontrado: the rev
# Documento já carregado ou não encontrado: avenged sevenfold
# Documento já carregado ou não encontrado: fox footy
# Documento já carregado ou não encontrado: herald sun
# Documento já carregado ou não encontrado: fox footy
# Documento já carregado ou não encontrado: herald sun
# Documento já carregado ou não encontrado: united states
# Documento já carregado ou não encontrado: judeo-iraqi arabic
# Documento já carregado ou não encontrado: maya civilization
# Documento já carregado ou não encontrado: black watch
# Documento já carregado ou não encontrado: suicidal tendencies
# Documento já carregado ou não encontrado: western hockey league
# Documento já carregado ou não encontrado: national hockey league
# Documento já carregado ou não encontrado: home run
# Documento já carregado ou não encontrado: minor league baseball
# Documento já carregado ou não encontrado: colonel
# Documento já carregado ou não encontrado: colonel
# Documento já carregado ou não encontrado: israel
# Documento já carregado ou não encontrado: harvard business review
# Documento já carregado ou não encontrado: american football
# Documento já carregado ou não encontrado: college football
# Documento já carregado ou não encontrado: united states
# Documento já carregado ou não encontrado: billboard 200
# Documento já carregado ou não encontrado: romeo discography
# Documento já carregado ou não encontrado: billboard 200
# Documento já carregado ou não encontrado: master p
# Documento já carregado ou não encontrado: hip hop history
# Documento já carregado ou não encontrado: billboard 200
# Documento já carregado ou não encontrado: louisiana
# Documento já carregado ou não encontrado: arizona
# Documento já carregado ou não encontrado: state farm stadium
# Documento já carregado ou não encontrado: louisiana
# Documento já carregado ou não encontrado: united states
# Documento já carregado ou não encontrado: gulf of mexico
# Documento já carregado ou não encontrado: saffir–simpson scale
# Documento já carregado ou não encontrado: forgotten realms
# Documento já carregado ou não encontrado: list of dungeons & dragons rulebooks
# Documento já carregado ou não encontrado: mexico
# Documento já carregado ou não encontrado: napoleon iii
# Documento já carregado ou não encontrado: american football
# Documento já carregado ou não encontrado: national football league
# Documento já carregado ou não encontrado: protagonist
# Documento já carregado ou não encontrado: double dragon
# Documento já carregado ou não encontrado: world war ii
# Documento já carregado ou não encontrado: banff, alberta
# Documento já carregado ou não encontrado: american football
# Documento já carregado ou não encontrado: quarterback
# Documento já carregado ou não encontrado: college football
# Documento já carregado ou não encontrado: 2009 nfl draft
# Documento já carregado ou não encontrado: new york city
# Documento já carregado ou não encontrado: los angeles
# Documento já carregado ou não encontrado: metal massacre
# Documento já carregado ou não encontrado: metal massacre
# Documento já carregado ou não encontrado: hull city a.f.c.
# Documento já carregado ou não encontrado: everton f.c.
# Documento já carregado ou não encontrado: everton f.c.
# Documento já carregado ou não encontrado: soviet union
# Documento já carregado ou não encontrado: world hockey association
# Documento já carregado ou não encontrado: fa cup
# Documento já carregado ou não encontrado: mets de guaynabo (basketball)
# Documento já carregado ou não encontrado: mets de guaynabo (basketball)
# Documento já carregado ou não encontrado: mario morales coliseum
# Documento já carregado ou não encontrado: mario morales coliseum
# Documento já carregado ou não encontrado: guaynabo fluminense fc
# Documento já carregado ou não encontrado: puerto rico soccer league
# Documento já carregado ou não encontrado: guaynabo fluminense fc
# Documento já carregado ou não encontrado: recording industry association of america
# Documento já carregado ou não encontrado: united kingdom
# Documento já carregado ou não encontrado: ice hockey
# Documento já carregado ou não encontrado: canada
# Documento já carregado ou não encontrado: university of toronto
# Documento já carregado ou não encontrado: the pittsburgh press
# Documento já carregado ou não encontrado: rock and roll
# Documento já carregado ou não encontrado: spanish civil war
# Documento já carregado ou não encontrado: boston brawlers
# Documento já carregado ou não encontrado: sony
# Documento já carregado ou não encontrado: world series
# Documento já carregado ou não encontrado: national league
# Documento já carregado ou não encontrado: bruce lee
# Documento já carregado ou não encontrado: shandong
# Documento já carregado ou não encontrado: continental divide of the americas
# Documento já carregado ou não encontrado: shankh monastery
# Documento já carregado ou não encontrado: the emperor jones
# Documento já carregado ou não encontrado: napoleon
# Documento já carregado ou não encontrado: belgium
# Documento já carregado ou não encontrado: detroit pistons
# Documento já carregado ou não encontrado: english channel
# Documento já carregado ou não encontrado: royal australian navy
# Documento já carregado ou não encontrado: republic of china navy
# Documento já carregado ou não encontrado: order of the red banner
# Documento já carregado ou não encontrado: harper's magazine
# Documento já carregado ou não encontrado: morris museum of art
# Documento já carregado ou não encontrado: midwestern united states
# Documento já carregado ou não encontrado: french union
# Documento já carregado ou não encontrado: dismissal of james comey
# Documento já carregado ou não encontrado: national basketball association
# Documento já carregado ou não encontrado: australia
# Documento já carregado ou não encontrado: cape town
# Documento já carregado ou não encontrado: jerusalem
# Documento já carregado ou não encontrado: r.e.m.
# Documento já carregado ou não encontrado: new york city
# Documento já carregado ou não encontrado: canada
# Documento já carregado ou não encontrado: southampton
# Documento já carregado ou não encontrado: the bahamas
# Documento já carregado ou não encontrado: quebec
# Documento já carregado ou não encontrado: ministry of commerce and industry (india)
# Documento já carregado ou não encontrado: licence raj
# Documento já carregado ou não encontrado: river thames
# Documento já carregado ou não encontrado: athens
# Documento já carregado ou não encontrado: professional wrestling match types
# Documento já carregado ou não encontrado: rob van dam
# Documento já carregado ou não encontrado: professional wrestling authority figures
# Documento já carregado ou não encontrado: world war ii
# Documento já carregado ou não encontrado: pop music
# Documento já carregado ou não encontrado: g (musical note)
# Documento já carregado ou não encontrado: world war i
# Documento já carregado ou não encontrado: english channel
# Documento já carregado ou não encontrado: river thames
# Documento já carregado ou não encontrado: canada
# Documento já carregado ou não encontrado: provinces and territories of canada
# Documento já carregado ou não encontrado: germany
# Documento já carregado ou não encontrado: bbc
# Documento já carregado ou não encontrado: member of parliament
# Documento já carregado ou não encontrado: karl marx
# Documento já carregado ou não encontrado: fascism
# Documento já carregado ou não encontrado: dallas cowboys
# Documento já carregado ou não encontrado: national football league
# Documento já carregado ou não encontrado: jason witten
# Documento já carregado ou não encontrado: italy national football team
# Documento já carregado ou não encontrado: usl championship
# Documento já carregado ou não encontrado: a-league (1995–2004)
# Documento já carregado ou não encontrado: national professional soccer league (1984–2001)
# Documento já carregado ou não encontrado: professor
# Documento já carregado ou não encontrado: michigan state university
# Documento já carregado ou não encontrado: algeria
# Total de documentos: 2186

# %%
#@title Divisão de texto em pedaços (Chunking)

# Cria uma instância do divisor de texto recursivo com uma lista de separadores padrão
text_splitter = RecursiveCharacterTextSplitter(
    # Lista de separadores padrão
    separators=["\n\n", "\n", " ", ""],
    chunk_size=1500,        # Tamanho máximo do pedaço (chunk) em caracteres
    chunk_overlap=100,      # Sobreposição entre pedaços para manter contexto
    length_function=len,    # Função para calcular o comprimento de cada pedaço
    is_separator_regex=False,  # Define se os separadores são regex ou não (nesse caso, não são)
)

# Cria uma lista com os conteúdos dos documentos
contents = [doc['content'] for doc in documents]

# Função para dividir um único conteúdo em pedaços
def split_content(content):
    return text_splitter.split_text(content)

# Divisão do conteúdo em pedaços menores (chunking) usando processamento paralelo
def split_contents_in_chunks(contents):
    chunks = []
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(split_content, content): content for content in contents}
        for future in as_completed(futures):
            try:
                chunks.extend(future.result())
            except Exception as e:
                print(f"Erro ao processar conteúdo: {e}")
    return chunks

# Chama a função para dividir os conteúdos
chunks = split_contents_in_chunks(contents)

# Imprime o número total de pedaços gerados
print(f'Total de pedaços: {len(chunks)}')

# Imprime o comprimento dos primeiros 10 pedaços
print("\nComprimento dos primeiros 10 pedaços:")
print([len(text) for text in chunks[:10]])

# Exibe um exemplo do primeiro pedaço gerado
print("\n===> Mostrar um exemplo <===")
print(chunks[0])
# Out:
# Total de pedaços: 59941
#
# Comprimento dos primeiros 10 pedaços:
# [1290, 1461, 1233, 1159, 281, 1118, 1493, 578, 1378, 1348]
#
# ===> Mostrar um exemplo <===
# The Scottsdale Scorpions are a baseball team that plays in the East Division of the <a href="Arizona%20Fall%20League">Arizona Fall League</a> located in <a href="Scottsdale%2C%20Arizona">Scottsdale, Arizona</a>. They play their home games at <a href="Scottsdale%20Stadium">Scottsdale Stadium</a>.
#
# Team history.In the fall of 1994, the team gained worldwide media attention, when <a href="Michael%20Jordan">Michael Jordan</a> joined the Scorpions after playing his first minor league baseball season with the Double-A <a href="Birmingham%20Barons">Birmingham Barons</a> in <a href="Birmingham%2C%20Alabama">Birmingham, Alabama</a>.
#
# The Scorpions won their first championship in 1996 against the <a href="Mesa%20Saguaros">Mesa Saguaros</a>.
#
# The Scorpions would make the championship game in 2002, 2004, and 2005 but would fail to win it. For the 2005 season, the team played its games in <a href="Surprise%2C%20Arizona">Surprise, Arizona</a> due to renovations of Scottsdale Stadium. The team returned to Scottsdale Stadium the following year only to be named the Grand Canyon Scorpions. The team would change their name back to the Scottsdale Scorpions in the 2007 season.
#
# They would win the championship in 2010, the first time in fourteen years. They also won the championship in 2015.

# %%
# @title Baixar modelo para calcular embeddings

def load_embedding_model(model_name: str = "sentence-transformers/all-mpnet-base-v2") -> HuggingFaceEmbeddings:
    """
    Carrega o modelo de embeddings da Hugging Face.

    Args:
        model_name (str): Nome do modelo a ser carregado.

    Returns:
        HuggingFaceEmbeddings: Instância do modelo de embeddings.
    """
    try:
        model_emb = HuggingFaceEmbeddings(model_name=model_name)
        return model_emb
    except Exception as e:
        print(f"Erro ao carregar o modelo {model_name}: {e}")
        raise

def generate_embedding(model_emb: HuggingFaceEmbeddings, text: str) -> list:
    """
    Gera o embedding para um texto fornecido.

    Args:
        model_emb (HuggingFaceEmbeddings): Modelo de embeddings.
        text (str): Texto de entrada.

    Returns:
        list: Vetor de embedding.
    """
    try:
        query_result = model_emb.embed_query(text)
        return query_result
    except Exception as e:
        print(f"Erro ao gerar embedding para o texto: {e}")
        raise

# Cache para o modelo de embeddings
embedding_model_cache = {}

def get_embedding_model(model_name: str) -> HuggingFaceEmbeddings:
    """
    Obtém o modelo de embeddings, utilizando cache para evitar recargas desnecessárias.

    Args:
        model_name (str): Nome do modelo a ser obtido.

    Returns:
        HuggingFaceEmbeddings: Instância do modelo de embeddings.
    """
    if model_name not in embedding_model_cache:
        embedding_model_cache[model_name] = load_embedding_model(model_name)
    return embedding_model_cache[model_name]

# Nome do modelo a ser usado
model_name = "sentence-transformers/all-mpnet-base-v2"

# Obtém o modelo de embeddings
model_emb = get_embedding_model(model_name)

# Define um texto de exemplo para gerar embeddings
text = "This is a test document."

# Gera o embedding para a consulta usando o texto de exemplo
query_result = generate_embedding(model_emb, text)

# Exemplo para mostrar como gerar embeddings
def display_embedding_example(text: str, embedding: list):
    """
    Exibe um exemplo de como gerar embeddings.

    Args:
        text (str): Texto de entrada.
        embedding (list): Vetor de embedding gerado.
    """
    print("\n\nExemplo para gerar embeddings")
    print(f'Texto de entrada: {text}')
    print(f'Tamanho do embedding: {len(embedding)}')
    print(f'Exemplo do embedding: {embedding[:3]}')  # Mostra os primeiros 3 valores do embedding

# Chama a função para exibir o exemplo
display_embedding_example(text, query_result)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Exemplo para gerar embeddings
# Texto de entrada: This is a test document.
# Tamanho do embedding: 768
# Exemplo do embedding: [-0.04895172640681267, -0.039861924946308136, -0.021562771871685982]

# %%
# @title Calcular embeddings para cada pedaço (chunk)

# Função para calcular o embedding de um único chunk
def compute_embedding(chunk: str, model_emb) -> List[float]:
    try:
        embedding = model_emb.embed_query(chunk)
        return embedding
    except Exception as e:
        print(f"Erro ao calcular embedding para um chunk: {e}")
        return None  # Retorna None em caso de erro

# Função para calcular embeddings para uma lista de chunks
def compute_embeddings_for_chunks(chunks: List[str], model_emb, max_workers: int = 4) -> List[List[float]]:
    embeddings_list = []  # Lista para armazenar os embeddings de cada pedaço

    # Utiliza ThreadPoolExecutor para processamento paralelo
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submete todas as tarefas ao executor
        futures = {executor.submit(compute_embedding, chunk, model_emb): chunk for chunk in chunks}

        # Utiliza tqdm para exibir a barra de progresso
        for future in tqdm(as_completed(futures), total=len(futures), desc="Calculando embeddings"):
            chunk = futures[future]
            embedding = future.result()
            if embedding is not None:
                embeddings_list.append(embedding)
            else:
                print(f"Embedding não calculado para o chunk: {chunk[:30]}...")  # Mostra início do chunk problemático

    return embeddings_list

# Chama a função para calcular os embeddings dos chunks
embeddings_list = compute_embeddings_for_chunks(chunks, model_emb)

# Imprime o número total de embeddings gerados
print(f'Total de embeddings: {len(embeddings_list)}')

# Verifica se a lista de embeddings não está vazia antes de acessar o primeiro elemento
if embeddings_list:
    # Imprime a dimensão dos embeddings gerados
    print(f"Dimensão do embedding: {len(embeddings_list[0])}")
else:
    print("Nenhum embedding foi calculado.")
# Out:
# Calculando embeddings: 100%|██████████| 59941/59941 [24:49<00:00, 40.25it/s]
# Total de embeddings: 59941
# Dimensão do embedding: 768

# %%
# @title Criar índice FAISS

def create_faiss_index(embeddings_list, index_file_path='index_file.index'):
    """
    Cria e salva um índice FAISS a partir de uma lista de embeddings.

    Args:
        embeddings_list (list): Lista de embeddings (listas ou arrays numpy).
        index_file_path (str): Caminho do arquivo para salvar o índice FAISS.

    Returns:
        index: Índice FAISS criado.
    """
    import numpy as np
    import faiss

    # Verifica se a lista de embeddings não está vazia
    if not embeddings_list:
        raise ValueError("A lista de embeddings está vazia.")

    # Converte a lista de embeddings para um array numpy
    embeddings_array = np.array(embeddings_list).astype('float32')

    # Verifica se todos os embeddings têm a mesma dimensão
    dimension = embeddings_array.shape[1]
    if not all(len(embedding) == dimension for embedding in embeddings_array):
        raise ValueError("Todos os embeddings devem ter a mesma dimensão.")

    # Escolha do tipo de índice FAISS com base no tamanho do dataset
    num_embeddings = embeddings_array.shape[0]
    if num_embeddings < 10000:
        # Para conjuntos pequenos, IndexFlatL2 é adequado
        index = faiss.IndexFlatL2(dimension)
    else:
        # Para conjuntos maiores, usar índice IVF (Inverted File Index)
        nlist = 100  # Número de listas (ajuste conforme necessário)
        quantizer = faiss.IndexFlatL2(dimension)
        index = faiss.IndexIVFFlat(quantizer, dimension, nlist, faiss.METRIC_L2)
        # Treina o índice IVF
        index.train(embeddings_array)

    # Adiciona os embeddings ao índice
    index.add(embeddings_array)

    # Salva o índice em um arquivo para uso posterior
    faiss.write_index(index, index_file_path)

    print(f"Índice FAISS criado e salvo em '{index_file_path}'.")

    return index

# Exemplo de uso da função
index_file_path = 'index_file.index'
index = create_faiss_index(embeddings_list, index_file_path)
# Out:
# Índice FAISS criado e salvo em 'index_file.index'.

# %%
# @title Carregar o índice FAISS salvo

def load_faiss_index(index_file_path: str = 'index_file.index'):
    """
    Carrega o índice FAISS a partir de um arquivo salvo.

    Args:
        index_file_path (str): Caminho do arquivo de índice FAISS.

    Returns:
        faiss.Index: Índice FAISS carregado.

    Raises:
        FileNotFoundError: Se o arquivo de índice não for encontrado.
        Exception: Para outros erros durante o carregamento do índice.
    """
    try:
        index = faiss.read_index(index_file_path)
        print(f"Índice FAISS carregado de '{index_file_path}'.")
        return index
    except FileNotFoundError:
        print(f"Erro: Arquivo de índice '{index_file_path}' não encontrado.")
        raise
    except Exception as e:
        print(f"Erro ao carregar o índice FAISS: {e}")
        raise

# Exemplo de uso da função
index = load_faiss_index('index_file.index')
# Out:
# Índice FAISS carregado de 'index_file.index'.

# %%
# @title Recuperar pedaços (chunks)

def generate_query_embedding(query: str, model) -> np.ndarray:
    """
    Gera o embedding para a consulta fornecida.

    Args:
        query (str): Texto da consulta.
        model: Modelo de embeddings utilizado.

    Returns:
        np.ndarray: Embedding da consulta.
    """
    try:
        query_embedding = model.embed_query(query)
        query_embedding = np.array([query_embedding]).astype('float32')
        return query_embedding
    except Exception as e:
        print(f"Erro ao gerar embedding para a consulta: {e}")
        raise

def search_index(query_embedding: np.ndarray, index, k: int) -> np.ndarray:
    """
    Realiza a busca no índice FAISS com o embedding da consulta.

    Args:
        query_embedding (np.ndarray): Embedding da consulta.
        index: Índice FAISS para busca.
        k (int): Número de resultados a serem retornados.

    Returns:
        np.ndarray: Índices dos pedaços mais similares.
    """
    try:
        distances, indices = index.search(query_embedding, k)
        return indices
    except Exception as e:
        print(f"Erro ao buscar no índice FAISS: {e}")
        raise

def retrieve_chunks(query: str, k: int, model, chunks: List[str], index) -> List[str]:
    """
    Recupera os k pedaços mais similares a uma consulta fornecida.

    Args:
        query (str): Texto da consulta.
        k (int): Número de pedaços a serem retornados.
        model: Modelo de embeddings utilizado.
        chunks (List[str]): Lista de pedaços de texto.
        index: Índice FAISS para busca.

    Returns:
        List[str]: Lista dos pedaços mais similares à consulta.
    """
    try:
        # Gera o embedding da consulta
        query_embedding = generate_query_embedding(query, model)
        # Realiza a busca no índice FAISS
        indices = search_index(query_embedding, index, k)
        # Recupera os pedaços correspondentes
        retrieved_chunks = [chunks[i] for i in indices[0]]
        return retrieved_chunks
    except Exception as e:
        print(f"Erro ao recuperar os pedaços: {e}")
        return []

# Exemplo de consulta para gerar o embedding
query = "Your search query here"

# Recupera os 5 documentos mais similares à consulta
similar_docs = retrieve_chunks(query, k=5, model=model_emb, chunks=chunks, index=index)

# Imprime a consulta e os pedaços recuperados
print(f"Consulta: {query}")
print("Pedaços Recuperados:")
for i, doc in enumerate(similar_docs):
    print(f"[Documento {i+1}] : {doc}")
    print("--------------------")
# Out:
# Consulta: Your search query here
# Pedaços Recuperados:
# [Documento 1] : </li><li>- <a href="https%3A//www.myspace.com/popsearch/">Official Myspace page for POPSearch 2007</a>
# </li></ul>
# --------------------
# [Documento 2] : </li><li>- <a href="Liquid%20crystal%20tunable%20filter">Liquid crystal tunable filter</a>
# </li><li>- <a href="List%20of%20Earth%20observation%20satellites">List of Earth observation satellites</a>
# </li><li>- <a href="Mobile%20mapping">Mobile mapping</a>
# </li><li>- <a href="Multispectral%20pattern%20recognition">Multispectral pattern recognition</a>
# </li><li>- <a href="National%20Center%20for%20Remote%20Sensing%2C%20Air%20and%20Space%20Law">National Center for Remote Sensing, Air and Space Law</a>
# </li><li>- <a href="National%20LIDAR%20Dataset">National LIDAR Dataset</a>
# </li><li>- <a href="Orthophoto">Orthophoto</a>
# </li><li>- <a href="Pictometry">Pictometry</a>
# </li><li>- <a href="Radiometry">Radiometry</a>
# </li><li>- <a href="Remote%20monitoring%20and%20control">Remote monitoring and control</a>
# </li><li>- <a href="Remote%20sensing%20%28archaeology%29">Remote sensing (archaeology)</a>
# </li><li>- <a href="Remote%20sensing%20satellite%20and%20data%20overview">Remote sensing satellite and data overview</a>
# </li><li>- <a href="Satellite%20imagery">Satellite imagery</a>
# </li><li>- <a href="Sonar">Sonar</a>
# </li><li>- <a href="Space%20probe">Space probe</a>
# </li><li>- <a href="TopoFlight">TopoFlight</a>
# </li><li>- <a href="Vector%20Map">Vector Map</a>
# </li>Further reading.<li>- US Army FM series.
# </li><li>- US Army military intelligence museum, FT Huachuca, AZ
# --------------------
# [Documento 3] : and <a href="1st%20Foreign%20Parachute%20Regiment">Ariège</a> in the Aures and the last in Kabylie.
# --------------------
# [Documento 4] : </li><li>- <a href="Ahmad%20Band">Ahmad Band</a>
# </li><li>- <a href="Andra%20and%20The%20BackBone">Andra and The BackBone</a>
# </li></ul>
# External links.<ul><li>- <a href="https%3A//web.archive.org/web/20090624053041/http%3A//www.dewa19.com/">Official site</a>
# </li></ul>
# --------------------
# [Documento 5] : <a href="ExxonMobil">ExxonMobil</a>, <a href="FedEx">FedEx</a>, <a href="Kraft%20Foods">Kraft Foods</a>, <a href="Leo%20Pharma">LEO Pharma Americas</a>, <a href="Microsoft">Microsoft</a>, <a href="Yahoo%21">Yahoo!</a>, <a href="Oracle%20Corporation">Oracle</a>, <a href="Sony">Sony</a>, <a href="NortonLifeLock">Symantec</a>, <a href="Visa%20Inc.">Visa</a>, and <a href="Walmart">Walmart</a>. Additionally, companies based in nearby cities or unincorporated areas of <a href="Miami-Dade%20County%2C%20Florida">Miami-Dade County</a> include <a href="Bacardi">Bacardi</a>, <a href="Benihana">Benihana</a>, <a href="Burger%20King">Burger King</a>, <a href="Carnival%20Cruise%20Line">Carnival Cruise Line</a>, <a href="Navarro%20Discount%20Pharmacies">Navarro Discount Pharmacies</a>, <a href="Perry%20Ellis%20International">Perry Ellis International</a>, <a href="Ryder">Ryder</a>, <a href="Sedano%27s">Sedano's</a>, <a href="UniM%C3%A1s">UniMás</a>, <a href="Univision">Univision</a>, and <a href="U.S.%20Century%20Bank">U.S. Century Bank</a>.
# --------------------

# %%
# @title Funções

# Cria uma instância do cliente Groq, usando a chave de API fornecida
client = Groq(
    api_key=API_KEY,
)

def generate_prompt(docs: List[str], question: str) -> str:
    """
    Gera um prompt para o modelo a partir dos documentos e da pergunta.

    Args:
        docs (List[str]): Lista de documentos relevantes.
        question (str): Pergunta do usuário.

    Returns:
        str: Prompt formatado para o modelo.
    """
    # Instruções iniciais para o prompt adaptadas do segundo código
    prompt = ("Write an explanation to the answer given the documents and the question. "
              "It is important that you cite all the relevant documents. "
              "Use this format: {explanation}: 'str'\n {short answer}: 'str' \n\n")
    # Adiciona cada documento ao prompt
    for i, doc in enumerate(docs, 1):
        prompt += f"[Document {i}]: {doc}\n\n"
    # Adiciona a pergunta e solicita a resposta
    prompt += f"Question: {question}\n\nAnswer: \n\nExplanation:"
    return prompt

def extract_true_answer(hit: Dict[str, Any]) -> str:
    """
    Extrai a resposta verdadeira do item fornecido.

    Args:
        hit (Dict[str, Any]): Dicionário contendo a informação da pergunta e resposta.

    Returns:
        str: Resposta verdadeira extraída.
    """
    answer = hit.get('answer', {})
    answer_type = answer.get('type', '')
    true_answer = ""

    if answer_type == 'span':
        true_answer = ", ".join([a['text'] for a in answer.get("answer_spans", [])])
    elif answer_type == 'value':
        true_answer = f"{answer.get('answer_value', '')} {answer.get('answer_unit', '')}".strip()
    elif answer_type == 'binary':
        true_answer = answer.get('answer_value', '')
    else:
        print(f"Tipo de resposta não suportado: {answer_type}")
    return true_answer

def answer_questions(user_questions: List[Dict[str, Any]], k: int = 3) -> Dict[str, List[str]]:
    """
    Responde a uma lista de perguntas fornecidas pelo usuário.

    Args:
        user_questions (List[Dict[str, Any]]): Lista de perguntas e informações associadas.
        k (int): Número de documentos similares a serem recuperados.

    Returns:
        Dict[str, List[str]]: Dicionário com perguntas, respostas geradas e respostas verdadeiras.
    """
    results = {
        "question": [],
        "content": [],
        "answer": [],
        "explanation": []
    }

    for item in tqdm(user_questions, desc="RAG"):
        try:
            # Extrai a pergunta
            question_data = item.get('questions', [{}])[0]
            query = question_data.get('question', '')

            # Recupera os pedaços de texto mais similares à pergunta
            similar_docs = retrieve_chunks(query, k=k, model=model_emb, chunks=chunks, index=index)

            # Gera o prompt usando os documentos similares e a pergunta
            prompt = generate_prompt(similar_docs, query)

            # Responde à pergunta usando um modelo de linguagem grande (LLM)
            rag_response = client.chat.completions.create(
                messages=[
                    {
                        "role": "user",
                        "content": prompt,
                    }
                ],
                model="llama-3.2-11b-text-preview",
            )

            # Processar a resposta para separar a explicação e a resposta curta
            rag_answer = rag_response.choices[0].message.content
            rag_answer_lower = rag_answer.lower()

            # Verifica se a resposta contém "{short answer}" e "{explanation}" ou "short answer:"
            if "{short answer}" in rag_answer_lower and "{explanation}" in rag_answer_lower:
                # Separar usando os placeholders {explanation} e {short answer}
                explanation = rag_answer.split("{explanation}:")[1].split("{short answer}:")[0].strip().strip("'\"")
                short_answer = rag_answer.split("{short answer}:")[1].strip().strip("'\"")
            elif "short answer:" in rag_answer_lower:
                # Separar com "short answer:"
                split_index = rag_answer_lower.find("short answer:")
                explanation = rag_answer[:split_index].strip()
                short_answer = rag_answer[split_index + len("short answer:"):].strip()
            else:
                short_answer = rag_answer.strip()
                explanation = ''

            # Extrai a resposta verdadeira
            true_answer = extract_true_answer(question_data)

            # Armazena os resultados
            results["question"].append(query)
            results["content"].append(short_answer)
            results["answer"].append(true_answer)
            results["explanation"].append(explanation)

        except Exception as e:
            print(f"Erro ao processar a pergunta: {e}")
            continue

    return results

# %%
# @title Debug

import random

def display_results(results: dict):
    """
    Exibe uma amostra dos resultados obtidos após responder às perguntas.

    Args:
        results (dict): Dicionário contendo as perguntas, respostas verdadeiras e respostas geradas.
    """
    # Obtém o número de perguntas respondidas
    n = len(results.get("question", []))
    if n == 0:
        print("Nenhum resultado disponível para exibir.")
        return

    print("\n\n===> Exemplo <===")
    for i in range(n):
        # Verifica se as chaves existem no dicionário antes de acessar
        question = results["question"][i] if i < len(results["question"]) else "Pergunta não disponível"
        true_answer = results["answer"][i] if i < len(results["answer"]) else "Resposta verdadeira não disponível"
        generated_answer = results["content"][i] if i < len(results["content"]) else "Resposta gerada não disponível"

        # Imprime a pergunta, a resposta verdadeira e a resposta gerada pelo modelo
        print(f"Pergunta: {question}")
        print(f"Resposta verdadeira: {true_answer}")
        print(f"Resposta gerada: {generated_answer}")
        print("-----------------------------\n")

# Define o número de perguntas a serem selecionadas aleatoriamente
num_samples = 2

# Seleciona aleatoriamente 'num_samples' itens dos dados filtrados
random_samples = random.sample(filter_data, num_samples)

# Chama a função para responder às perguntas selecionadas aleatoriamente
results = answer_questions(random_samples)

# Exibe uma amostra dos resultados
display_results(results)
# Out:
# RAG: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
# ===> Exemplo <===
# Pergunta: Did the two Eastern Front battles spearheaded by shock troops take place in the same country?
# Resposta verdadeira: no
# Resposta gerada: 'No'
# -----------------------------
#
# Pergunta: How long had the Spruce Grove Mets been a team when they won the Centennial Cup?
# Resposta verdadeira: 1 year
# Resposta gerada: They had been a team for 11 years when they won the Centennial Cup'.
# -----------------------------

# %%
# @title Executar tudo

def execute_all(filter_data: list, num_questions: int =150) -> dict:
    """
    Executa o processo de resposta às perguntas e retorna os resultados.

    Args:
        filter_data (list): Lista de dados filtrados contendo as perguntas.
        num_questions (int): Número de perguntas a serem respondidas.

    Returns:
        dict: Dicionário com as perguntas, respostas geradas e respostas verdadeiras.
    """
    try:
        # Chama a função para responder às perguntas, usando os primeiros 'num_questions' itens dos dados filtrados
        results = answer_questions(filter_data[:num_questions])

        # Obtém o número total de perguntas respondidas
        total_questions = len(results.get("question", []))
        print(f'Total de perguntas: {total_questions}')

        return results

    except Exception as e:
        print(f"Erro ao executar todas as perguntas: {e}")
        return {}

# Exemplo de uso da função
results = execute_all(filter_data, num_questions=150)
# Out:
# RAG:  37%|███▋      | 55/150 [08:59<17:11, 10.85s/it]
# Erro ao processar a pergunta: list index out of range
# RAG:  50%|█████     | 75/150 [12:43<13:26, 10.76s/it]
# Erro ao processar a pergunta: list index out of range
# RAG:  60%|██████    | 90/150 [15:09<10:21, 10.36s/it]
# Erro ao processar a pergunta: list index out of range
# RAG:  80%|████████  | 120/150 [20:30<05:12, 10.42s/it]
# Erro ao processar a pergunta: list index out of range
# RAG: 100%|██████████| 150/150 [26:10<00:00, 10.47s/it]
# Total de perguntas: 146

# %%
# @title F1-BoW (Bag of Words)

# Função para tokenizar um texto, transformando em minúsculas e dividindo em palavras
def tokenize(text: str) -> List[str]:
    """
    Tokeniza o texto, convertendo para minúsculas e extraindo as palavras.

    Args:
        text (str): Texto a ser tokenizado.

    Returns:
        List[str]: Lista de tokens extraídos do texto.
    """
    import re
    # Utiliza expressão regular para extrair palavras, ignorando pontuação
    return re.findall(r'\b\w+\b', text.lower())

# Função para calcular a métrica F1 usando a abordagem Bag of Words
def bag_of_words_f1(reference: str, generated: str) -> float:
    """
    Calcula o F1-Score entre dois textos usando a abordagem Bag of Words.

    Args:
        reference (str): Texto de referência (resposta verdadeira).
        generated (str): Texto gerado pelo modelo.

    Returns:
        float: Valor do F1-Score entre 0 e 1.
    """
    # Tokeniza as respostas de referência e gerada
    ref_tokens = tokenize(reference)
    gen_tokens = tokenize(generated)

    # Converte para Counter (bag of words)
    ref_bag = Counter(ref_tokens)
    gen_bag = Counter(gen_tokens)

    # Caso ambos os conjuntos estejam vazios
    if not ref_bag and not gen_bag:
        return 1.0  # Considera correspondência perfeita

    # Caso um dos conjuntos esteja vazio
    if not ref_bag or not gen_bag:
        return 0.0  # Sem correspondência possível

    # Calcula a interseção dos tokens
    common_tokens = ref_bag & gen_bag
    correct = sum(common_tokens.values())

    # Se não houver tokens em comum
    if correct == 0:
        return 0.0

    # Calcula precisão e recall
    precision = correct / sum(gen_bag.values())
    recall = correct / sum(ref_bag.values())

    # Evita divisão por zero na fórmula do F1-Score
    if precision + recall == 0:
        return 0.0

    # Cálculo do F1-Score
    f1 = (2 * precision * recall) / (precision + recall)

    return f1

# Exemplo para testar a função
reference = "This is an example reference text."
generated = "This text is an example!"

# Calcula o F1-BoW entre a resposta verdadeira e a resposta gerada
f1 = bag_of_words_f1(reference, generated)

# Imprime o exemplo e o resultado do F1-BoW
print("Exemplo de F1-BoW")
print(f"Resposta verdadeira: {reference}")
print(f"Resposta gerada pelo modelo: {generated}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Exemplo de F1-BoW
# Resposta verdadeira: This is an example reference text.
# Resposta gerada pelo modelo: This text is an example!
# F1-Score: 0.9091

# %%
# @title Avaliação de Performance


def evaluate_performance(results: dict) -> float:
    """
    Avalia o desempenho calculando o F1-Score médio para as respostas geradas.

    Args:
        results (dict): Dicionário contendo as perguntas, respostas verdadeiras e respostas geradas.

    Returns:
        float: O F1-Score médio das respostas.
    """
    try:
        # Obtém as listas de respostas verdadeiras e geradas
        true_answers = results.get("answer", [])
        generated_answers = results.get("content", [])
        num_questions = len(results.get("question", []))

        # Verifica se as listas têm o mesmo tamanho
        if not (len(true_answers) == len(generated_answers) == num_questions):
            print("Erro: O número de perguntas, respostas verdadeiras e respostas geradas não correspondem.")
            return 0.0

        if num_questions == 0:
            print("Nenhuma pergunta foi respondida.")
            return 0.0

        f1_scores = []  # Lista para armazenar o F1-Score de cada pergunta

        # Itera sobre todas as perguntas e calcula o F1-Score para cada par resposta verdadeira/resposta gerada
        for i in range(num_questions):
            true_answer = true_answers[i]
            generated_answer = generated_answers[i]
            f1 = bag_of_words_f1(true_answer, generated_answer)
            f1_scores.append(f1)

        # Calcula o F1-Score médio
        mean_f1_score = np.mean(f1_scores)

        # Imprime o número total de perguntas e o F1-Score médio
        print(f"Total de perguntas: {num_questions}")
        print(f"F1-Score médio: {mean_f1_score:.4f}")

        return mean_f1_score

    except Exception as e:
        print(f"Erro ao avaliar o desempenho: {e}")
        return 0.0

# Exemplo de uso da função
mean_f1 = evaluate_performance(results)
# Out:
# Total de perguntas: 146
# F1-Score médio: 0.1314

# %%
def display_results(results: dict):
    """
    Exibe uma amostra dos resultados obtidos após responder às perguntas.

    Args:
        results (dict): Dicionário contendo as perguntas, respostas verdadeiras e respostas geradas.
    """
    # Obtém o número de perguntas respondidas
    n = len(results.get("question", []))
    if n == 0:
        print("Nenhum resultado disponível para exibir.")
        return

    print("\n\n===> Exemplo <===")
    for i in range(n):
        # Verifica se as chaves existem no dicionário antes de acessar
        question = results["question"][i] if i < len(results["question"]) else "Pergunta não disponível"
        true_answer = results["answer"][i] if i < len(results["answer"]) else "Resposta verdadeira não disponível"
        generated_answer = results["content"][i] if i < len(results["content"]) else "Resposta gerada não disponível"

        # Imprime a pergunta, a resposta verdadeira e a resposta gerada pelo modelo
        print(f"Pergunta: {question}")
        print(f"Resposta verdadeira: {true_answer}")
        print(f"Resposta gerada: {generated_answer}")
        # Adiciona um indicador se a resposta está correta ou não
        if true_answer == generated_answer:
            print("Resultado: ✅ Resposta correta")
        else:
            print("Resultado: ❌ Resposta incorreta")
        print("-----------------------------\n")

# Exibe uma amostra dos resultados
display_results(results)
# Out:
# ===> Exemplo <===
# Pergunta: What is Zeus know for in Greek mythology?
# Resposta verdadeira: sky and thunder god
# Resposta gerada: Bearer of the Aegis and various other roles such as king of the gods, patron of the marketplace and keeper of oaths.
#
# According to [Document 1] and [Document 2], Zeus has many roles and epithets in Greek mythology. [Document 2] provides specific examples of his various roles, such as:
#
# - Zeus Aegiduchos or Aegiochos, who is the bearer of the Aegis, a divine shield with Medusa's head on it.
# - Zeus Agoraeus, who is the patron of the marketplace and punisher of dishonest traders.
# - Zeus Areius, who is warlike or the atoning one.
# - Zeus Horkios, who is the keeper of oaths and has a sanctuary at Olympia where exposed liars would dedicate a votive statue to him.
# - Zeus Olympios, who is the king of the gods and patron of the Panhellenic Games at Olympia.
# - Zeus Panhellenios, who is worshipped on Aeacus's temple on Aegina.
# - Zeus Xenios, Philoxenon, or Hospites, who is the patron of hospitality and guests.
#
# This information is also supported by [Document 3], which mentions the various roles and characteristics of gods and goddesses, including Zeus, in ancient Greek mythology.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long had the First World War been over when Messe was named aide-de-camp?
# Resposta verdadeira: 5 years
# Resposta gerada: 5 years
# Resultado: ✅ Resposta correta
# -----------------------------
#
# Pergunta: How long had Angela Scoular been acting professionally when she appeared in the movie "On Her Majesty's Secret Service"?
# Resposta verdadeira: 2 years
# Resposta gerada: Around 10 years (starting around 1960 if she began modeling at 17) before her appearance in "On Her Majesty's Secret Service".
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What is the capacity of the stadium where Brunt returned to action after a torn ACL?
# Resposta verdadeira: 26,688
# Resposta gerada: However, I can provide an explanation for the capacity of The Hawthorns, the home stadium of West Bromwich Albion.
#
#  {Explanatin}: The capacity of The Hawthorns increased to 25,000+ in the mid-1990s after the stadium became all-seated following the Taylor Report. [Document 2]
#
#  {Short answer}: Over 25,000 (in the mid-1990s).
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In which country was Wilhelm Müller born?
# Resposta verdadeira: Germany
# Resposta gerada: Germany
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In which Italian region did Pesce studied medicine?
# Resposta verdadeira: Liguria
# Resposta gerada: There is no answer available.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: When was the sports organization that the Turks and Caicos Islands became affiliate members in 2002 founded?
# Resposta verdadeira: 1909
# Resposta gerada: No information was found.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many teams play in the NHL?
# Resposta verdadeira: 31
# Resposta gerada: The National Hockey League currently has 31 teams (Document 2).
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who is the mayor of the city where the album was mixed by Andy Wallace?
# Resposta verdadeira: Bill de Blasio
# Resposta gerada: I'm going to answer the unexpected question by using indirect and connected data points.
#
# First, let's identify the mix engineer for the album (I couldn't find specific data provided), instead I used the audio mastering engineer:
#
#  {explanation}: The album release information wasn't given, but according to general knowledge, R.E.M.s album 'Accelerate' (2008) wasn't produced by Andy Wallace. However we can look at other data.
#
# Next, according to general knowledge from previous releases some albums by R.E.M. worked with Andy Wallace (Mixing and Mastering).
# For Example.
# Murmur was mixed by Don Dixon, John Fry, and Stephen Hague, but don't quote me for other data like previous released - 'Document'. [1]
#
# However unreleased sources contain a list of engineers and production details for other records released that use Andy Wallace as the Mix engineer.
#
# Mixing Engineer of some well documented albums of the Alternative Rock (genre) like Faith No More's 'Angel Dust'...
# Since additional R.E.M. audio detail was given in other data, one reported album from this Genre isn't the focus to answer the "unexpected" question.
#
# In  "Accelerate" from "Recorded at Kung Foo Sound & GrungeIsDead  - Los Angeles, Ca" contains no audio information from document 3.
#
# But R.E.M did employ 'Kung Foo Sound' though from an unexpected and 'cited' document.
#
# The citations then came from (Document 2). which involves those additional <a href="session%20musician">session musicians</a>.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long had Alex Rance been a professional player when he suffered an ACL injury during a season opening match?
# Resposta verdadeira: 11 Years
# Resposta gerada: He damaged knee ligaments.
#
# 2. In [Document 3], There's no mention of the player having ACL injury. It mentions that Jonny Evans underwent surgery to repair an ankle injury.
#
#    Explanation: Jonny Evans suffered an ankle injury.
#
#    Short answer: There's no information about Alex Rance suffering an ACL injury.
#
# Since there's no information about Alex Rance, we will skip him and only use the information about Dickov.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In what country is the city located where the Arabic dialect is spoken by Jews?
# Resposta verdadeira: Iraq
# Resposta gerada: Israel/Palestine
#
#
# [Citations]:
# - Document 1: [Not cited, as it needs to reformatted according to requested format]
# - Document 2: https://en.wikipedia.org/wiki/Arab%20Jewish%20tribes
#  (Additional link: https://en.wikipedia.org/wiki/Arab%20Jewish%20communities)
# - Document 3: https://en.wikipedia.org/wiki/Flavius%20Josephus
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many years were there between Pompeii's destruction and the discovery of the Maya site of Cerén?
# Resposta verdadeira: 1897 years
# Resposta gerada: 1600 years.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which university did Don Branby played college football for?
# Resposta verdadeira: Colorado Buffaloes
# Resposta gerada: Oklahoma State University.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long had the Perthshire Regiment been a going concern for when Harison joined it as a captain?
# Resposta verdadeira: 69 years
# Resposta gerada: Firstly, the answer provided doesn't explicitly relate to the question. The question pertains to the tenure of the Perthshire Regiment at the time the narrator (Harison) became a part of the battalion. However, the information in the given documents appears to focus more on different facts related to the Perthshire Regiment's history, equipment, changes, and current status.
#
# However, looking closely at the history of the Perthshire Regiment's commanding officers mentioned in the Document 2 we may be able to form an idea of the period when any of these officers could be associated with when such a question might be posed. LT-Gen. Benjamin Orlando Jones is the 1st commander listed but there is a gap in information flow and the timeline does not exactly list the tenure period they each had in charge.
#
# But it does start with an ending date 1865. There are commanding officers such as  Lt-Gen. Benjamin Orlando Jones, and Gen. Sir Henry Robert Ferguson-Davie listed with start dates prior to 1865 but no specific date for "Harison".
#
# Thus with the available data and background the explanation may come:
#
# "Unfortunately, we do not have enough data to provide the exact amount of time the Perthshire Regiment was a going concern before Captain Harison became part of it."
#
# {short answer}: 'Unfortunately, we do not have enough data to provide the exact amount of time.'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: When was the company for which Tookey called a protest for founded?
# Resposta verdadeira: 7 May 1946
# Resposta gerada: Explanation: The company for which Tookey called a protest regarding the potential founding of its predecessor entity is Jann Wenner's <i>Rolling Stone</i> magazine, however there is no text within the reference given from that entity about 'Tookie Williams'.
#
# [Jann Wenner is known as the co-founder of Rolling Stone. However there is insufficient given from the provided sources to indicate his role as founder in the events in question but appears at Document 2.]
#
# However the closest correlation is that the given founding of News Communications was cited within Document 1 was founded in 1994 by Jerry Finkelstein.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which team won the first game in the 2004 National League Division Series?
# Resposta verdadeira: Cardinals
# Resposta gerada: Explanation: The question asks for the winner of the first game in the 2004 National League Division Series. To determine this, we need to refer to the provided documents.
#
#  {short answer}: 'Los Angeles Dodgers'
#
# Document 1 mentions the 2004 National League Division Series (NLDS), where the champions of the three NL divisions and a "wild card" team participated in two best-of-five series.
#
# According to Document 1, the first game was between the St. Louis Cardinals (Central Division champion) and the Los Angeles Dodgers (Western Division champion). The document states: "(1) St. Louis Cardinals (Central Division champion, 105–57) vs. (3) Los Angeles Dodgers (Western Division champion, 93–69): Cardinals win series, 3–1."
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was the Grand Olympic Auditorium at the time of New Regime playing a landmark concert there?
# Resposta verdadeira: 60 years
# Resposta gerada: 31 years"
#
# The XPW event (Freefall) was held on February 23, 2002. According to [Document 1], the Grand Olympic Auditorium was built in 1924 and had its grand opening on August 5, 1925. This means that the venue was approximately 77 years old at the time of its grand opening. However, considering the event was held in 2002, we can calculate its age at that time. 2002 minus 1924 is 78 years. This means that it was 78 years old when the event was held. However, given the information I can provide, the problem is confusing as it doesn't ask for New Regime info, it would be actually 78 years old at the time of XPW event, but for a "landmark" event to take place that actually occurred in the documents 31 would refer to information not present
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who owned the Rochester Rhinos when Glenn left the team?
# Resposta verdadeira: Rochester, New York,
# Resposta gerada: Explanation: There is no information about someone named 'Glenn' in the provided documents.
#
# However, since the response question was about 'Glenn', I can infer that 'Glenn' refers to Steve Glenn, whose name is not found in the information but a similar name is 'Jesse Myers' and another is 'Pat Ercoli'. Also, a similar name is 'Bob Lilley' but that information is relevant to Glenn's departure and replacement. [Document 1]:
#   I can tell that the correct explanation for "who owned the Rochester Rhinos when Glenn left" refers to after 'Bob Lilley' was replaced by Jesse Myers in [Document 1] - Jesse Myers was the Head Coach after Glenn.
#
# However, another suitable name for Glenn can be found in searching for the role for "Head Coach". We know that after they left club was headed by 'Bob Lilley (soccer)' [Document 1].
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many championship appearances has the team where Ashton played junior hockey had?
# Resposta verdadeira: 5 appearances
# Resposta gerada: <Could not be determined specifically as the given information does not include complete listing of the achievements of ASHKAWANDER when playing for the Saskatoon Blades.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Had the Chicago White Sox been around longer than the Birminham Barons when he was assigned to the White Sox's minor league system?
# Resposta verdadeira: yes
# Resposta gerada: Explanation: The Chicago White Sox and the Birmingham Barons have a historical connection through their farm system. Based on the provided documents, we can see that Don Wakins was assigned to the Birmingham Barons but that is not in the documents and instead it was the Minor League affiliations assignment given that the documents point to as minor league system assignments.
#
#  Document 2 suggest that McKeon worked in the farm system of the Washington Senators franchise and its successor, the Minnesota Twins.
#
# [Document 1]: does not help here
#
# However, the Document 2 reveal the following farm system assignments for McKeon but none for Birmingham:
# Triple-A assignments for
#
#  - Vancouver Mounties (1962),
#  - Dallas-Fort Worth Rangers (1963) and
# - Omaha Royals (1969-72) for the “ Kansas city Royals” a contemporary to “columbiana and other American league Western division and later a part east but more recently Missouri east central east and southeast and most southeast parts plus more region ( ) with later home in Missouri, part USA and there not related before ,  Kansas City “
#
#
#  None in Birmingham barons
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was the person who shot Waitkus the year he was shot?
# Resposta verdadeira: 20 years
# Resposta gerada: {Explanation}: The person who shot Waitkus was Steinhagen, but there seems to be a mistake in the question provided. The correct question should be asking about the year Steinhagen was shot, but according to available documents, Steinhagen did not shoot Waitkus.
#
# However, according to the documents provided, Steinhagen left no immediate survivors at the time of her death in 2012. To clarify, it was actually a woman named Ruth Steinhagen who tried to shoot Waitkus, not someone named Steinhagen who was the perpetrator. However, there is information on another Ruth Steinhagen who died in 2012.
#
# To find a similar connection to the question provided, we can look at the provided information about Edith 'Ed' Steinhagen taken from a different section. Here it is: On December 29, 2012, Edith 'Ed' Steinhagen died in a Chicago hospital of a subdural hematoma that she suffered as a result of an accidental fall in her home. Since we have Edith 'Ed' Steinhagen dying in the same year as specified by the question, and there is another connection, according to other information.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In what race was Sohn Kee-chung the gold medalist?
# Resposta verdadeira: marathon
# Resposta gerada:
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Was Eduard van Beinum still alive whnen Gilmore retired?
# Resposta verdadeira: no
# Resposta gerada: Explanation: Unfortunately, there is not enough information provided in the given documents to answer the question about Eduard van Beinum's status when Gilmore retired.
#
# However, based on the question, it seems that there is a historical context or sequence of events mentioned involving Eduard van Beinum and Gilmore. If we are to compare the sequences and events in the provided documents, we notice that Eduard van Beinum is associated with Document 2 as an actor/acting teacher. On the other hand, Gilmore cannot be found in the given documents.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was Licerio Gerónimo when Private Bonifacio Mariano killed General Henry Ware Lawton?
# Resposta verdadeira: 44 years
# Resposta gerada: {explanation}: Licerio Gerónimo and Private Bonifacio Mariano were not directly involved in the death of General Henry Ware Lawton. However, the general who opposed Lawton at the Battle of San Mateo was Licerio Gerónimo. Lawton's death occurred on December 19, 1899, during the Battle of Paye, but it was at San Mateo.
#
# However, Private Bonifacio Mariano did not kill General Lawton. According to historical records, the death of Lawton happened during the skirmish with insurgent forces led by Licerio Gerónimo, but the number of casualties during the skirmish indicates that Lawton met his death in some form of a battle, not during a direct confrontation with Private Bonifacio Mariano.
#
# As private Bonifacio Mariano is not named as the operator in any of these episodes described in documents.
#
# Private Bonifacio Mariano is not the person who killed general Henry ware lawton, The person who killed Lawton is missing from documents.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which of the battles Sherman fought during a winter campaign had higher Union casualty rate?
# Resposta verdadeira:  Donelson
# Resposta gerada: The answer to the question is not applicable as the question inaccurately states a winter campaign, when in fact the events described took place during the summer of 1864.
#
# Explanation citing relevant documents:
#
# * [Document 1]: The passage touches on the Atlanta campaign but does not specifically mention a winter campaign. The Atlanta campaign lasted for "a continuous battle of 120 days," fought from early May to September 1864 (not winter).
# * [Document 2]: Similar to Document 1, this also focuses on the Atlanta campaign and mentions the Battle of Kennesaw Mountain but does not refer to a winter campaign. Instead, it specifies the dates and the terrain as "mountainous."
# * [Document 3]: Although this document lists the starting composition of Sherman's forces and mentions the opposing Confederate Army, it does not allude to a winter campaign. It suggests the geographical difference in campaign force, but a seasonal difference in the U.S. 1864 context.
#
# Given these points, the Atlanta campaign discussed in the documents took place during June 1864 and is not representative of a winter campaign.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which country did some of the tribes escaped to after their deportation from northern Mexico?
# Resposta verdadeira: United States
# Resposta gerada: Explanation: Some of the Native American tribes, such as the Comanche, Apache, and Navajo, escaped to the United States after being forced to deal with the lack of effective governance, economic difficulties, and violent raids in northern Mexico.
#
# This information can be inferred from Document 1, which mentions that the Comanche and Apache were successful in raiding for livestock and looting much of northern Mexico outside the scattered cities, resulting in the death of thousands of Mexicans and causing disruptions to transportation and communications.
#
# (However) the correct answer comes from understanding the usage of a word in document 1 that gives the correct country 'United States' in the section that defines where many Indians drifted through.
#
#
# {short answer}: United States
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In what county did Hirsch study under Edward C. Tolman and Robert Tryon?
# Resposta verdadeira: United States
# Resposta gerada: Alameda
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What states do the roads that go around flathead lake end in?
# Resposta verdadeira: Arizona, Montana
# Resposta gerada: Explanation: The roads that go around Flathead Lake, as mentioned in Montana Highway 35 (MT 35) [Document 3], start at U.S. Highway 93 in Polson and end at U.S. Highway 2 in Kalispell. To determine the other end or the "end" in question, we must refer back to the Montana Highway 35 explanation.
#
# However, the actual question of what states the road goes into does not necessarily need to go around the data provided but can still be figured out.
#
# According to Montana Highway 35, the road begins at U.S. Highway 93 in Polson, Montana [Document 3], and ends at U.S. Highway 2 in Kalispell. U.S. Route 2 [Document 3] that it ends at starts at the Washington–Minnesota border [Document not provided], but we can guess some states it might pass through in order to verify the guess and make it come to an end as asked about with that the other way from previous information since information presented may never address the ending state near the mentioned 'border'. According to other documents that talk about US 6 [Document 1], it only goes into 14 states - none of which are near the border described for US Highways stated in document 3 of Washington and Minnesota.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What is the birthplace of the person who used Palmer's 1910 photograph of the illuminated Grand Pier Pavilion as found object art in his Note 78?
# Resposta verdadeira: Normandy, France
# Resposta gerada: Explanation: The person in question is likely Henri Matisse, but since his work isn't mentioned, there's little chance that Matisse is the correct answer, based on the document provided.
#
# The information points to Marcel Duchamp using the photograph of Palmer, however, this does not answer our question: Palmer's photograph was found in Note 78 by Marcel Duchamp.
#
# In Note 78, Duchamp referenced Edward Steichens images photographed originally using Palmer's photograph as a print to modify the image from before which was published.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Of the schools where Bernard Avishai taught, which one has the highest current enrollment?
# Resposta verdadeira: Duke University
# Resposta gerada: str'
# 26,848
#
# Please note documents do not mention enrollment information for higher cal - universities.
# If Bernard Avishai is associated with the mentioned Princeton and Hebrew studies Institution, more specific data is possible.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Of the universities where Paranikas studied, which was founded first?
# Resposta verdadeira: University of Munich
# Resposta gerada: Unfortunately, due to the lack of information on Paranikas' studies in the provided documents, we can't determine which university he attended or which one was founded first in the context of Paranikas' education.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Is Josh Heupel older than Scott Frost?
# Resposta verdadeira: no
# Resposta gerada: No answer
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long had Gorbacheve been in power before the attempted coup?
# Resposta verdadeira: 6 years
# Resposta gerada: Unknown, but before the August Coup in 1991."
#
# However, if we must infer based on what was documented about Gorbachev returning to power (Document 1 does not explicitly state the time he left power, just returned to it), the documents provided give some sequence of time but this time is indirect, especially on how much time passed between arriving to coup start, and returning initially to the powers.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many months was the Northwest Indian War?
# Resposta verdadeira: 120 months
# Resposta gerada: approximately 123 months
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In what city was Romeo's father born?
# Resposta verdadeira: New Orleans
# Resposta gerada: Explanation: This answer cannot be found in the given documents as they only discuss the lives of Virgil and Ovid, both Roman poets.
#
#  Short answer: 'Not Found'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long had the Spruce Grove Mets been a team when they won the Centennial Cup?
# Resposta verdadeira: 1 year
# Resposta gerada: Explanation: The team in question, the Spruce Grove Mets, was a part of the Alberta Junior Hockey League and won two consecutive Centennial Cups in 1975 and 1976 as the Mets. They were previously known as the Edmonton Western Movers (1963-1972) and the Edmonton Mets (1972-1974) based in Edmonton. However, it wasn't until they moved to Spruce Grove in 1975 that they became known as the Spruce Grove Mets.
#
#  {short answer}: 2
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which singer was younger when they recorded a cover of Madonna's song, Jody Watley or Nivek Ogre?
# Resposta verdadeira: Nivek Ogre
# Resposta gerada: Nivek Ogre was younger
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What was the first named storm of the 2019 hurricane season?
# Resposta verdadeira: Andrea
# Resposta gerada: {explanation}: The first named storm of the 2019 hurricane season was Subtropical Storm Andrea.
#
# However, since it formed before the official start of the season (June 1), another early storm is important to note when looking into named storms. The first officially recognized named storm of the 2019 hurricane season was Hurricane Barry.
#
# More information can be found in Document [2]. According to this document, the first named storm formed on July 11 when Subtropical Storm Andrea did not count towards the named storm total due to what happened to it further. Firstly, it went named as Barry (Document 2: "After the dissipation of Three less than 24 hours later, activity paused again." This would disqualify a name for the subsequent number, and instead Hurricane Barry took the number). Hurricane activity was most active on the season's later side of "late August with a few storms developing". Firstly a named storm formed August 24th named Chantal after its formation off the coast almost at the same time with another storm formation on 26th August closer to being named Hurricane Dorian (Document 2: "Hurricane activity was most active on the season's later side of 'late August with a few storms developing'"). The first one formed after sub tropical Andrea could therefore not be the first officially named 'subtropical storm' titled subtropical "C" but could solely consider titled "Hurricane" Storm.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What was the construction cost of the stadium that the Cardinals moved into in Glendale, Arizona?
# Resposta verdadeira: $455 million
# Resposta gerada: ($455 million
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was Giuseppe Mazzini when Wolff began serving as his secretary?
# Resposta verdadeira: 55 years
# Resposta gerada: However, I don't see a question that mentions Giuseppe Mazzini and Wolff. I see Mazzini's residence and other details about him, but I don't see any information about Wolff and Mazzini's relationship.
#
# Therefore, I cannot provide an explanation to the answer.
#
# However, considering the given documents, I can tell you about Mazzini's life. The document mentions Mazzini's residence in London and a commemorative blue plaque marking the place. It also mentions a bust of Mazzini in New York's Central Park and an academic year named after him at the College of Europe.
#
# If you can provide the context or the specific question related to Mazzini and Wolff, I can try to help.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What is the population of the island nation that suffered minor damage from Hurricane Betsy?
# Resposta verdadeira: 332,634
# Resposta gerada: However, there is not enough information in any of the documents regarding which island nation suffered minor damage from Hurricane Betsy.
#
# One document (Document 2) states that Hurricane Betsy primarily affected areas of southern Florida and Louisiana, but it does not mention any specific island nation.
#
# If we need to provide a general explanation to the lack of information available regarding the island nation:
#
# These documents do not provide the requested information as they do not mention the population of an island nation that suffered minor damage from Hurricane Betsy.
#
#
# Populated islands affected by the hurricane mentioned in the documents:
#
#  * Florida is a US state not an island nation.
#  * Bahamas were affected by Hurricane Betsy (Document 2) but the island nation that could have suffered minor damage from Hurricane Betsy is not indicated by these data.
#
# Or you could redirect the question asking which island nation suffered more affected by Hurricane Betsy
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In what months did Hurricane Katrine and Hurricane Rita hit?
# Resposta verdadeira: August 2005, September, 2005
# Resposta gerada: September
#
#  Katrina formed over the Gulf of Mexico on August 23 (or not August; although that is not relevant) but hit the United States in late August 2005 which was not the time for Rita to hit the United States, however hurricane Katrine did have her peak winds in late August however hurricane Katrina primarily was in the state of Louisiana.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was John Cena when he interrupted Paul Heyman?
# Resposta verdadeira: 27 years
# Resposta gerada: Explanation: There is no information in the provided documents about John Cena interrupting Paul Heyman. The documents only discuss Paul Heyman's involvement with various WWE wrestlers, including Curtis Axel, CM Punk, and Chris Jericho. They also mention John Cena's rise to fame, but there is no mention of him interrupting Paul Heyman.
#
# However, we can infer that John Cena may have had interactions with Paul Heyman at some point in his career, given that Heyman was managing Curtis Axel and was associated with Punk's storyline around the time of Payback.
#
#  {short answer}: None.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was Ed Greenwood when he wrote an article in Dragon #54?
# Resposta verdadeira: 22 years
# Resposta gerada: Explanation: The question about Ed Greenwood's age at the time he wrote an article in Dragon #54 is not directly answered by the provided documents. However, Document 2 states that the articles began to be published in The Dragon magazine starting from its 30th issue in 1979. As Ed Greenwood discovered the Dungeons & Dragons game in 1975 and began writing stories about the Forgotten Realms as a child, starting in the mid-1960s, it's possible to calculate his age. In Document 1, it is stated that Ed Greenwood was born in July 21, 1959.
#
# Using this information, if the first article was published in 1979, Ed Greenwood would have been around 20 years old (born July 1959, article published in 1979). However, the specific issue number that answers the question is not provided.
#
#  {short answer}: however, if he began writing at age 20 assume that he wrote his first article not the first in the series for number 54.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: When was the Mexican president that the Plan of Ayutla was aimed to remove first elected to office?
# Resposta verdadeira: 1833
# Resposta gerada: {explain}: 'The Plan of Ayutla aimed to remove Benito Juárez, who was first elected as the president of Mexico on December 21, 1857, making him the target of the opposition Conservative faction.'
#
#  {short answer}: 'December 21, 1857'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which of the seas that surround the United Kingdom is the largest?
# Resposta verdadeira: The Atlantic Ocean
# Resposta gerada: Not possible to determine from provided documents.
#
# Note: The North Sea, as mentioned in [Document 2], covers a significant area of 570000 km2 and is bounded by the surrounding countries including the UK.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many students attend the college that Community Transit operates local routes to?
# Resposta verdadeira: 46,000
# Resposta gerada: 6,595
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What year was the General Motors Corporation founded?
# Resposta verdadeira: 1908
# Resposta gerada: 1908
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which team won the first championship of the league that the Los Angeles Chargers play in?
# Resposta verdadeira:  Akron Pros
# Resposta gerada: Explanation: The Chargers' counterpart in this question would be the San Francisco 49ers and not the Los Angeles Chargers, as the Chargers are the team being asked about their relationship with. The Los Angeles Chargers were part of the American Football League (AFL), which merged with the National Football League (NFL) to form the modern-day NFL.
#
# The first championship won by the Los Angeles Chargers happens to be an AFL title. According to the documents, the Chargers won their only AFL title {afl title} in the "1963 American Football League playoffs" (Document 1).
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who was the youngest man to play Templeton Peck?
# Resposta verdadeira: Bradley Cooper
# Resposta gerada: Tim Dunigan
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long did Neo Geo survive as a console after Double Dragon was released on it?
# Resposta verdadeira: 12 years
# Resposta gerada: Explanation: According to Document 1, the last official game by SNK for the Neo Geo system was Samurai Shodown V Special, which was released in 2004. It was mentioned in Document 2 that the Neo Geo hardware production lasted until 1997. However, the Neo Geo system survived as a software platform for arcade systems for about 7 years after the hardware production stopped, and for another 7 years after Double Dragon was released.
#
# So the Neo Geo survived as a software platform for arcade systems for about 14 years after Double Dragon was released, considering Double Dragon was also released for Neo Geo in 1995.
#
# {short answer}: approximately 14 years
#
# [Document references]:
# 1. Document 1: The last official game by SNK for the Neo Geo system was released in 2004, and hardware production stopped in 1997.
# 2. Document 2: The AES console was discontinued in 1997, but game software production lasted until 2004, making Neo Geo the longest supported arcade system of all time.
# 3. Document 3: Although Double Dragon released a different version on the Neo Geo platform, the given answer is about the Neo Geo hardware and software console system itself.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Was World War II still going on when the Red Army was left Magdeburg?
# Resposta verdadeira: yes
# Resposta gerada: Explanation: The question concerns the events surrounding the Red Army during World War II, specifically whether the war was still ongoing when the Red Army occupied Magdeburg. It's known from historical records that the Red Army was successful in its operations against Nazi Germany, and by January 1945, Soviet military might was aimed at the German capital of Berlin. This implies that the Red Army was still engaged in combat against the German Army.
#
# However, the specific details about Magdeburg are not directly mentioned in the provided documents.
#
# But considering [Document 1]: The final battle in the area occurred near the city of Magdeburg, in the Battle of Berlin that took place at the end of World War II. Based on [Document 2]: After the summer of 1944, the Red Army continued to push the Germans westwards until they reached the outskirts of Eastern Germany. By January 1945, Soviet military might was aimed at the German capital of Berlin. By [Document 3]: By the summer of 1944 the German Wehrmacht is increasingly in retreat, suggesting the German forces were suffering defeats, it can be inferred that by the time the Battle of Berlin occurred which left the Red Army still engaged in combat Nazi Germany was losing the war. Considering that the Battle for Berlin fell to the Red Army in May 1945
#
# Therefore, The war was still going on when the Red Army occupied Magdeburg, and Magdeburg was likely to be part of the area which fell in the Battle of Berlin. Nazi Germany ended up defeated on May 8, 1945.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What year did Michael Jordan retire from the Washington Wizards?
# Resposta verdadeira: 2003
# Resposta gerada: The year in which Michael Jordan retired from the Washington Wizards is not directly mentioned in the provided documents. However, we can infer that Michael Jordan initially retired from the Washington Wizards in early 1999 after stating that he was returning "for the love of the game" but had to divest himself of any ownership of the team (Document 1).
#
# However, Jordan's second retirement from the Washington Wizards can be determined by document 3. It states that Michael Jordan retired for a second time in January 1999 and subsequently came out of retirement to play for Washington (Document 1) in 2001; but after the injury his full return to a regular player did not continue for the whole NBA season.
#
# Since it cannot be definitively concluded from the documents that all NBA seasons Michael Jordan played for Washington included a full return for him and his injury list retirement, and even the second full year that Michael Jordan played with the Wizards concluded, 2002-2003, the second year would include the January 1999 statement by Michael Jordan about returning, hence explaining why specific year for  'second full season' would be in the files record.
#
# However, document 3 also states that Jordan retired for a second time in January 1999 and came back out to play for his second full season to represent Washington that ended the following year.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many seasons have there been of the show that starred actress Nicollette Sheridan?
# Resposta verdadeira: eight
# Resposta gerada: There is not a straightforward answer to the question, as it is not specified which show is being referred to. However, based on the provided documents, we can identify multiple shows that starred Nicollette Sheridan.
#
# Document 2 mentions that Sheridan played Paige Matheson on the CBS primetime soap opera "Knots Landing" from 1986 to 1993, implying a total of 7 seasons. Additionally, Document 1 mentions that the pilot episode of the planned soap series "Dark Mansions" aired as a television movie in 1986, but it did not go to series.
#
# Without more specific information about the show that is being asked about, it is difficult to provide a definitive answer.
#
# However, if we assume that the question is referring to "Desperate Housewives", Nicollette Sheridan played the role of Edie Britt from 2004 to 2012, which was a total of 8 seasons. Document 3 mentions her time on the show, including her nominations and awards.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Is Banff National Park bigger than Jasper National Park?
# Resposta verdadeira: Jasper National Park
# Resposta gerada: Explanation: It is not possible to determine which park is bigger based on the provided documents, as no direct comparison between the sizes of Banff National Park and Jasper National Park is made.
#
#  {short answer}: 'No answer found'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who is the wife of the man who was named the world's richest in 2015?
# Resposta verdadeira:  Melinda French
# Resposta gerada: Unfortunately, the specific answer to the question cannot be directly determined using the provided information.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In which state did Mark Sanchez play college football?
# Resposta verdadeira: California
# Resposta gerada: California
# Resultado: ✅ Resposta correta
# -----------------------------
#
# Pergunta: Who played guitar for Suffocation when Incantation was formed?
# Resposta verdadeira: Guy Marchais, Todd German, Josh Barohn
# Resposta gerada: None mentioned from this information as the time frame occurred differently.
#
# The question "Who played guitar for Suffocation when Incantation was formed?" refers to the time period of when Incantation was formed in 1991, but all the initial guitarists for Suffocation were already in the band in the late 1980s.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: When was the record label owned by Brian Slagel founded?
# Resposta verdadeira: 1982
# Resposta gerada: Explanation: The answer to the question is not directly related to any of the provided documents, as they do not mention the record label owned by Brian Slagel. However, based on external knowledge, the record label Metal Blade Records, which was co-founded by Brian Slagel in 1981, is listed in one of the documents ([Document 2]Metal Blade Records was mentioned).
#
#  {short answer}: Not specified, but Metal Blade Records was co-founded by Brian Slagel in 1981
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was John Wayne when the original story for the film "In Old California" was written?
# Resposta verdadeira: 35 years
# Resposta gerada: Unfortunately, there is no information about the original story for the film "In Old California" in the provided documents. However, since you asked me to cite documents while writing the explanation, I can see that "In Old California" was not mentioned anywhere. However, I can still point you to relevant information.
#
# Explanation: Based on the provided documents, we were not able to find any information about the original story for the film "In Old California". The documents do discuss another unproduced film pitch, titled "Streets of Larado", but there is no such information available for "In Old California".
#
#  {short answer}: Not stated
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which of the non-rural-themed shows canceled by CBS in 1971 was aired first?
# Resposta verdadeira: Hogan's Heroes
# Resposta gerada: None.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What is the length of the body of water that L-28B  crosses before meeting Skyline Drive?
# Resposta verdadeira: 290 mi
# Resposta gerada: Explanation: The body of water that L-28B crosses before meeting Skyline Drive is the Elkhorn River, according to Document 2.
#
#  {short answer}: The Elkhorn River
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What age was Billy Jones when Duncan made his debut?
# Resposta verdadeira: 31 years
# Resposta gerada: There is no answer regarding "Billy Jones" in the provided documents. However, there are mentions of several basketball players and individuals, including K. C. Jones.
#
# One possible individual who could be referred to is Billy Cunningham's playing partner, but Cunningham, along with Jones as his partner did not appear in the provided data, both excepted to have been given a later name.
#
#  Assuming the mention you're referring to is K. C. Jones. K. C. Jones was an American basketball player and coach.
#
# Explanation of K. C. Jones' career in relation to Billy Cunningham's debut opponent (1997 playoffs for the Seattle team's second title win against the Jordan Michael-led Chicago Bulls team, but an injury was an issue at an earlier opponent in the regular season):
#
# Although there is some information present about players competing against Billy Cunningham including 'Billy "Easy Money'' Cunningham', but any explanation relies heavily on the specific information available about the individual that matches the surname you look for without causing an issue in proper data retrieval.
#
# As there is no direct information relating to an athlete given the name 'Billy Jones' (for example - this name is not referenced as part of Team data (The 'new monsters on block', formerly in Washington D.C. And have won a super bowl and playoff round a few NBA championships in previous eras.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What is the population of the city where Pearson worked in a shipping office?
# Resposta verdadeira: 466,415
# Resposta gerada: Explanation: The population of the city where Pearson worked in a shipping office is not explicitly mentioned in the provided documents. However, based on the context, it appears that Pearson worked in London, England.
#
#  [Document 1] does not mention Pearson. New York City is generally referred to in [Document 2] and is not associated with Pearson's work. Also, most of the other sisters mentioned from [Document 3] aren't plausible matches considering the shipping industry would have been in the UK in the past.
#
# However [Document 3] does not mention Pearson. It seems that Pearson worked somewhere else, as their workplace isn't referenced.
#
# Unfortunately the provided documents do not provide enough information to pinpoint the population of the city where Pearson worked.
#
# Note: Pearson is often associated with South London (not mentioned) it isn't contained in supplied information. In general an old office may refer to London
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many acres in size is the famous park where they will visit in later stanzas?
# Resposta verdadeira: 843 acre.
# Resposta gerada: 90-acre.
#
# [Document 1]: The wealth of greenspace afforded by Chicago's parks is further augmented by the <a href="Cook%20County%20Forest%20Preserves">Cook County Forest Preserves</a>, a network of open spaces containing forest, <a href="prairie">prairie</a>, <a href="wetland">wetland</a>, streams, and lakes that are set aside as natural areas which lie along the city's outskirts, including both the <a href="Chicago%20Botanic%20Garden">Chicago Botanic Garden</a> in <a href="Glencoe%2C%20Illinois">Glencoe</a> and the <a href="Brookfield%20Zoo">Brookfield Zoo</a> in <a href="Brookfield%2C%20Illinois">Brookfield</a>. <a href="Washington%20Park%20%28Chicago%20park%29">Washington Park</a> is also one of the city's biggest parks; covering nearly 400 acres. The park is listed on the <a href="National%20Register%20of%20Historic%20Places%20listings%20in%20South%20Side%20Chicago">National Register of Historic Places listings in South Side Chicago</a>.
#
# [Document 2]: </li><li>- <a href="Washington%20Square%20Park">Washington Square Park</a> is a prominent landmark in the <a href="Greenwich%20Village">Greenwich Village</a> neighborhood of Lower Manhattan. The <a href="Washington%20Square%20Arch">Washington Square Arch</a> at the northern gateway to the park is an iconic symbol of both <a href="New%20York%20University">New York University</a> and Greenwich Village.
# </li><li>- <a href="Prospect%20Park%20%28Brooklyn%29">Prospect Park</a> in Brooklyn has a 90 acre <a href="meadow">meadow</a>, a lake, and extensive <a href="woodland">woodlands</a>. Within the park is the historic Battle Pass, prominent in the Battle of Long Island.
# </li><li>- <a href="Flushing%20Meadows%E2%80%93Corona%20Park">Flushing Meadows–Corona Park</a> in Queens, with its 897 acres making it the city's fourth largest park, was the setting for the <a href="1939%20New%20York%20World%27s%20Fair">1939 World's Fair</a> and the <a href="1964%20New%20York%20World%27s%20Fair">1964 World's Fair</a> and is host to the <a href="USTA%20Billie%20Jean%20King%20National%20Tennis%20Center">USTA Billie Jean King National Tennis Center</a> and the annual <a href="US%20Open%20%28tennis%29">United States Open Tennis Championships</a> tournament.
#
# [Document 3]: <a href="Izmaylovsky%20Park">Izmaylovsky Park</a>, created in 1931, is one of the largest urban parks in the world along with <a href="Richmond%20Park">Richmond Park</a> in London. Its area of 15.34 km2 is six times greater than that of <a href="Central%20Park">Central Park</a> in New York.
#
# ...
#
# Specifically using that the survivor series took place at Molson center arena on November 15 1998.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many years had Sheffield united been in existence when Cisak made his club debut against the team?
# Resposta verdadeira: 122 years
# Resposta gerada: **Explanation**: As there is no specific information provided about Sheffield United being in existence when Cisak made his club debut against the team, I was unable to determine how many years the club had been in existence at that time.
#
# However, I found the following information in the documents:
#
# - Document 2 mentions that Sheffield United was formed in 1889.
# - Document 1 mentions that the club contested the Steel City derby with Sheffield Wednesday.
#
# But still, there is no information available about Cisak joining any of their matches.
#
# **Short answer**: 'There is no information.'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who are the members of the music group that provided production twice on the album American Gangster, including the single "Blue Magic?"
# Resposta verdadeira: Pharrell Williams, Chad Hug
# Resposta gerada: Ruff Ryders.
#
# Explanation: According to the discography listed in the supporting documents, the Ruff Ryders were a music production company founded by  DMX (who is listed in the Discography under Master P). Initially it consisted of three members: DMX,  Swizz Beatz,  and  Kool Sheik.  Dave East  provided instrumentation, while Swizz Beatz produced the work.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Did Jack Ikin win a single game during the 1947/48 tour of the West Indies?
# Resposta verdadeira: no
# Resposta gerada: **Explanation**: There is no relevant information about the 1947/48 tour of the West Indies in the provided documents. The documents mention India's first Test series in England in 1932, the Commonwealth XI tour of India in 1950-51, and the captaincy of Mansoor Ali Khan Pataudi, Ajit Wadekar, Srinivasaraghavan Venkataraghavan, and Bishen Singh Bedi. However, none of the documents provide information about Jack Ikin or the 1947/48 tour of the West Indies.
#
# **Short answer**: No information found
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was Lyndon Johnson when he won the Presidency for the first time?
# Resposta verdadeira: 45 years
# Resposta gerada: Explanation: Lyndon Johnson's first term as President of the United States began on November 22, 1963, after he assumed the presidency following the assassination of President John F. Kennedy. However, since Johnson took office after the assassination of Kennedy, it was not his 'first time elected' to the presidency. We are looking for the date of his first term in the U.S. Presidential election.
#
# To find this answer we have to go back in 1960 where Johnson ran for the Democratic nomination in the presidential election making history along with John F. Kennedy.
#
# [Document 2]: shows Johnson was the running mate of John Kennedy but Johnson became the president after Kennedy's assassination.
#
# The most relevant Document is [Document 1] showing Johnson  took office on November. However from [Document 2] we can find Johnson was running together with Kennedy.
#
# Document says Johnson took office after Kennedy's death.
#
# The Document [Document 1] adds important detail and provides a timeline to add credence to the answer.
#
# Please add In the answer I use Johnson, Lyndon Johnson.
#
# Document 1 : dates Johnson took the office on "November 22, 1963" and this coincides with an existing timeline.
#
# First answer in document  shows, it says Johnson [took] office on November 22.
#
#
# With info from 2 docs. We can say  Johnson ran for prez in 1960. The docs dont' have the facts needed showing johnson age during that year.
# Lyndon Johnson's birth year is missing.
#
#
# [Document 3] shows LBJ (Lyndon Johnson's nickname) birthday, i is reported
# LBJ's birthday is given “August 27, 1908,” which would make him around 53 years old when he took office as presidential race was during   Johnson took office on November 22, 1963, and that he ran for the republican nomination in 1960 with Kennedy along with president election.
#
#
# The question is asking about the age of Johnson during his first term as a president.
# I answer it: 53 years old, on information given and this answer would not be: Johnson birth year which could have provided direct answer to  the query.
#
#
#  Johnson assumed the Presidency following the assassination of President John F. Kennedy. If answering were to just be 's.' , for Johnson to win the Presidency the first time he must have been at older age that that which would of be   asked. we can add explanation about Johnson’s age because age played specific role here.
#
#
# [short answer]: 53
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What year was the magazine founded that Thomas Inskeep wrote for?
# Resposta verdadeira: 2002
# Resposta gerada: Explanation: There is no information provided about Thomas Inskeep in the given documents, so it is not possible to determine the year the magazine was founded that he wrote for based on the provided information.
#
# However, Document 1 mentions the succession of editors of the magazine, including William Shawn (1951-87), Robert Gottlieb (1987-92), and Tina Brown (1992-98), but there is no mention of Thomas Inskeep.
#
# Document 2 provides a general history of the magazine Harper's, including its founding in 1850, but does not mention Thomas Inskeep.
#
# Document 3 discusses the magazine's editorial traditions and notable features, but again does not mention Thomas Inskeep.
#
# Since the documents do not contain any information about Thomas Inskeep, his year of writing for the magazine is unknown.
#
#  {short answer}: 'Not Available'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What American astronauts walked on the moon during the Apollo program?
# Resposta verdadeira: Charles "Pete" Conrad, Alan L. Bean, Alan Shepard, Edgar Mitchell, David Scott, Irwin, John Young, Charles Duke, Harrison H. Schmitt, Eugene Cernan
# Resposta gerada: Half of the 24 astronauts who left Earth's orbit and flew around the Moon walked on the Moon's surface.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was Krishna Raja Wadiyar IV when he created the Government Soap Factory?
# Resposta verdadeira: 32 years
# Resposta gerada: None
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: In what year was Vickers founded?
# Resposta verdadeira: 1828
# Resposta gerada: 1828
# Resultado: ✅ Resposta correta
# -----------------------------
#
# Pergunta: What's the difference between territories and provinces in Canada?
# Resposta verdadeira:  Unlike the provinces, the territories of Canada have no inherent sovereignty and have only those powers delegated to them by the federal government
# Resposta gerada: Explanation: The major difference between Canadian territories and provinces lies in their powers and authority. Provinces receive their powers from the Constitution Act, 1867 (formerly called the British North America Act, 1867), whereas territorial governments have powers delegated to them by the Parliament of Canada. Additionally, provinces are considered sovereign within certain areas, have a lieutenant governor as their representative, and are responsible for various social programs like healthcare, education, and welfare. In contrast, territories have no inherent sovereignty, have a commissioner rather than a lieutenant governor, and receive powers directly from the federal government.
#
#  {short answer}: Provinces and territories in Canada have different powers and authorities. Provinces are sovereign, have lieutenant governors, and are responsible for various social programs, whereas territories have no sovereignty, have commissioners, and receive powers from the federal government.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Was Aloys Pichler older than Bavarian Prince Leoplold when he died?
# Resposta verdadeira: no
# Resposta gerada: {explanation}: The question whether Aloys Pichler was older than Bavarian Prince Leopold when he died requires analysis of the dates provided in Document 1, which describes the life of Aloys Pichler. Document 1 mentions that Aloys Pichler died on June 3, 1874, at Siegdorf, near Trauenstein.
#
# It also mentions that Pichler was pardoned through the intervention of the Bavarian prince Leopold in 1874.
#
# However, there is no hint about how old Pichler was at the point of pardon or the date of his death. Unfortunately, we couldn't gather any age details from either Document 1.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who were the members of the band that inspired Tom Robinson to found a band in 1976?
# Resposta verdadeira: Johnny Rotten, Steve Jones, Paul Cook, Glen Matlock
# Resposta gerada: none
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How long did the Civil War sparked by the attempted arrest last?
# Resposta verdadeira: 9 years
# Resposta gerada: {explanation}: The provided answer does not directly respond to the question regarding the length of time the Civil War sparked by the attempted arrest lasted. However, we can infer that the question is referring to the violence and civil unrest events in Omaha, Nebraska, between 1881 and 1891.
#
# In Document 1, it mentions several instances of violence, labor disputes, and racial incidents, including the Camp Dump Strike, the hanging of Joe Coe, and other riots and civil unrest events in Omaha during this period.
#
# The events mentioned in Document 1 do not indicate a 'civil war' specifically. Instead, they describe instances of civil unrest, labor disputes, and racial violence.
#
# However, Document 3 mentions an uprising in Paris that led to a civil war, but this event occurred in the context of the coup of Louis-Napoleon Bonaparte in 1851. The document does not provide information on the duration of the civil war.
#
# To answer the question based on the information provided in Document 3:
#
# There was no civil war sparked by an attempted arrest in the documents.
#
# Using the information from Document 1, it doesn't provide the answer to how long did the Civil War sparked by the attempted arrest last.
#
# A better answer might be: there is no direct information provided about the Civil War in relation to an attempted arrest.
#
# If you replace Civil war with riots/civil unrest, the [short answer]: 'there is no direct answer provided'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Who was the author of document that Bordiga counterposed the dictatorship of the proletariat, to be implemented by the communist party based on?
# Resposta verdadeira: Karl Marx, Friedrich Engels
# Resposta gerada: Karl Marx and Friedrich Engels
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What were the names of the three British Muslim prisoners known as the Tipton Three?
# Resposta verdadeira: Ruhal Ahmed, Asif Iqbal, Shafiq Rasul
# Resposta gerada: Explanation: The Tipton Three were three British Muslim prisoners who were detained at Guantanamo Bay in Cuba. They were identified as Ruhal Ahmed, Asif Iqbal, and Shafiq Rasul.
#
# Answer:
# Ruhal Ahmed,
# Asif Iqbal,
# Shafiq Rasul
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What country did Gibbins and Edwards visit together in 1934 to study in the mountains?
# Resposta verdadeira: Uganda and the Democratic Republic of the Congo
# Resposta gerada: There is no clear mention of Gibbins and Edwards visiting any country together to study the mountains in 1934. Document 1 provides information about the people who accompanied Richard Harriman on his voyage, while Document 2 talks about the early European explorers of the Rocky Mountains. Document 3 discusses the Harriman expedition (which took place in 1899-1900, not in 1934) and its scientific approach.
#
# Assuming that the query was meant to ask about the Harriman expedition, the question remains unclear due to confusion with the timing and the people involved.
#
# If the correct question is about the Harriman expedition or any other relevant expedition, a revised answer should rely on Document 3 for the specifics of the expedition.
#
# Harriman 's voyage to the (Mount) (Alaskan) Yukon took place in 1899-1900.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How old was Jimmy Spencer when he replaced Hut Stricklin as Junior Johnson & Associates' driver?
# Resposta verdadeira: 36 years
# Resposta gerada: No information about replacement.
#
#
# If the question could be asking how much Hut Stricklin's release made room for Jimmy Spencer; there will be a different answer to the question as to the explanation. As Jimmy joined Junie Donlavey in the 1992 season once Stricklin was let go.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many teams were there in the NFL during the Cowboy's 59th season?
# Resposta verdadeira: 32
# Resposta gerada: Since there is no information provided about the Cowboys' team number or the league information in the given documents about the Cowboys' season specific to their 59th season, we will use the information in Document 3 to assume the time period when the Cowboys were founded as an expansion team.
#
# The Cowboys' franchise was founded in 1960 as an expansion team. The Cowboys have not participated in the NFL since 1960.
#
# However, since we are looking for the NFL team count in connection to the Cowboys' 59th season. This means we would use the NBA timeline and the NFL timeline together.
#
#  NFL's foundation is to have started with ten teams now but was founded in 1920 meaning if the Cowboys' had a 59th season it was after 1920+59 years.   The most recent information at this time however isn't complete.
#
#  However because we know from a comprehensive NFL timeline in this same year NFL ( National Football League) currently has 32 teams based more or less in multiple places since you do the math that there are currently NFL 32/ present.
#
#  {short answer}: '32'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Did Del Olmo win the 1994 FIFA World Cup for Mexico?
# Resposta verdadeira: no
# Resposta gerada: Explanation: 'Del Olmo did not win the 1994 FIFA World Cup for Mexico; in fact, Mexico was eliminated in the first round.'
#  {short answer}: 'No'
#
# Citation and explanation:
#
# Document 1 states that 'under coach Miguel Mejia Baron, del Olmo represented Mexico in that year's CONCACAF Gold Cup and made the squad for the 1994 FIFA World Cup, where he played in Mexico's first-round games against Norway, Ireland, and Italy.' This implies that del Olmo did participate in the 1994 FIFA World Cup but could not help the team advance beyond the first round.
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: How many times had the Milan derby been held the year that British TV failed to show any Italian football?
# Resposta verdadeira: 109 years
# Resposta gerada: Not possible to determine
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: What city did Abboud attend college in?
# Resposta verdadeira: Saint Paul, Minnesota
# Resposta gerada: 'None'
# Resultado: ❌ Resposta incorreta
# -----------------------------
#
# Pergunta: Which of the colleges that Bessey studied at was founded first?
# Resposta verdadeira: Harvard University
# Resposta gerada: Harvard University
# Resultado: ✅ Resposta correta
# -----------------------------
#
# Pergunta: How much time had passed between the beginning of the Battle for Tripoli and report of Gaddafi's family escape to Algeria?
# Resposta verdadeira: 9 days
# Resposta gerada: 4-5 days.
# Resultado: ❌ Resposta incorreta
# -----------------------------
